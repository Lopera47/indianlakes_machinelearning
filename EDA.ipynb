# %%
# This notebook is to find patterns in the data
# Install moduls
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from functions import *

# %%
# Read the data
data_lakes = pd.read_csv("in\Water_pond_tanks_2021.csv", encoding = 'cp1252')
data_lakes.head()
# Out:
#    STN\nCode                        Name of Monitoring Location  \
# 0     4368.0      KOLLERU LAKE KOKKIRAYALANKA (V), KAILALUR (M)
# 1     2353.0  KONDAKARLA-AAVA LAKE, PARAWADA PHARMA CITY, VI...
# 2     1790.0                       PULICATE LAKE , NELLORE DIST
# 3     4391.0      CHENGAMBAKAM TANK IN SRI CITY SEZ,\nTIRUPATHI
# 4     4921.0           ANNAMAYYA PROJECT ON CHEYYERU\nRESERVOIR
#
#   Type Water Body      State Name  TemperatureC (Min)  Temperature C (Max)  \
# 0            LAKE  ANDHRA PRADESH                24.0                 27.0
# 1            LAKE  ANDHRA PRADESH                26.0                 29.0
# 2            LAKE  ANDHRA PRADESH                18.0                 24.0
# 3            TANK  ANDHRA PRADESH                22.0                 29.0
# 4         Wetland  ANDHRA PRADESH                21.0                 30.0
#
#    Dissolved Oxygen (mg/L) (Min)  Dissolved Oxygen (mg/L) (Max)  pH (Min)  \
# ...

# %%
# Data Types
data_lakes.dtypes
# Out:
# STN\nCode                            float64
# Name of Monitoring Location           object
# Type Water Body                       object
# State Name                            object
# TemperatureC (Min)                   float64
# Temperature C (Max)                  float64
# Dissolved Oxygen (mg/L) (Min)        float64
# Dissolved Oxygen (mg/L) (Max)        float64
# pH (Min)                             float64
# pH (Max)                             float64
# Conductivity (?mhos/cm) (Min)        float64
# Conductivity (?mhos/cm) (Max)        float64
# BOD (mg/L) (Min)                     float64
# BOD (mg/L) (Max)                     float64
# Nitrate N + Nitrite N(mg/L) (Min)    float64
# Nitrate N + Nitrite N(mg/L) (Max)    float64
# Fecal Coliform (MPN/100ml) (Min)     float64
# Fecal Coliform (MPN/100ml) (Max)     float64
# Total Coliform (MPN/100ml) (Min)     float64
# Total Coliform (MPN/100ml) (Max)     float64
# dtype: object

# %%
# Data info
data_lakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   STN
# Code                           619 non-null    float64
#  1   Name of Monitoring Location        620 non-null    object
#  2   Type Water Body                    620 non-null    object
#  3   State Name                         620 non-null    object
#  4   TemperatureC (Min)                 617 non-null    float64
#  5   Temperature C (Max)                617 non-null    float64
#  6   Dissolved Oxygen (mg/L) (Min)      618 non-null    float64
#  7   Dissolved Oxygen (mg/L) (Max)      618 non-null    float64
#  8   pH (Min)                           620 non-null    float64
#  9   pH (Max)                           620 non-null    float64
#  10  Conductivity (?mhos/cm) (Min)      615 non-null    float64
# ...

# %%
# Reviewing data null
data_lakes.isnull().sum()
# In General the null data is less than 10% of lakes dataset, so I'm going to delete it
# Out:
# STN\nCode                             1
# Name of Monitoring Location           0
# Type Water Body                       0
# State Name                            0
# TemperatureC (Min)                    3
# Temperature C (Max)                   3
# Dissolved Oxygen (mg/L) (Min)         2
# Dissolved Oxygen (mg/L) (Max)         2
# pH (Min)                              0
# pH (Max)                              0
# Conductivity (?mhos/cm) (Min)         5
# Conductivity (?mhos/cm) (Max)         5
# BOD (mg/L) (Min)                      2
# BOD (mg/L) (Max)                      2
# Nitrate N + Nitrite N(mg/L) (Min)    52
# Nitrate N + Nitrite N(mg/L) (Max)    52
# Fecal Coliform (MPN/100ml) (Min)     52
# Fecal Coliform (MPN/100ml) (Max)     52
# Total Coliform (MPN/100ml) (Min)     52
# Total Coliform (MPN/100ml) (Max)     52
# dtype: int64

# %%
processed_data_lakes = data_lakes.dropna()
processed_data_lakes
# Out:
#      STN\nCode                        Name of Monitoring Location  \
# 0       4368.0      KOLLERU LAKE KOKKIRAYALANKA (V), KAILALUR (M)
# 1       2353.0  KONDAKARLA-AAVA LAKE, PARAWADA PHARMA CITY, VI...
# 2       1790.0                       PULICATE LAKE , NELLORE DIST
# 3       4391.0      CHENGAMBAKAM TANK IN SRI CITY SEZ,\nTIRUPATHI
# 4       4921.0           ANNAMAYYA PROJECT ON CHEYYERU\nRESERVOIR
# ..         ...                                                ...
# 615     1765.0  RABINDRASAROVAR NATIONAL LAKE,\nCALCUTTA, WEST...
# 616     2544.0                              SAHEBBANDH AT PURULIA
# 617     2522.0                        SINCHAL LAKE FOR DARJEELING
# 618     2521.0          WATER RESERVIOR AT DELO LAKE,\nDARJELLING
# 619     4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#     Type Water Body      State Name  TemperatureC (Min)  Temperature C (Max)  \
# 0              LAKE  ANDHRA PRADESH                24.0                 27.0
# ...

# %%
#object to category
processed_data_lakes.astype({
        "Type Water Body": "category",
        "State Name": "category"})
# Out:
#      STN\nCode                        Name of Monitoring Location  \
# 0       4368.0      KOLLERU LAKE KOKKIRAYALANKA (V), KAILALUR (M)
# 1       2353.0  KONDAKARLA-AAVA LAKE, PARAWADA PHARMA CITY, VI...
# 2       1790.0                       PULICATE LAKE , NELLORE DIST
# 3       4391.0      CHENGAMBAKAM TANK IN SRI CITY SEZ,\nTIRUPATHI
# 4       4921.0           ANNAMAYYA PROJECT ON CHEYYERU\nRESERVOIR
# ..         ...                                                ...
# 615     1765.0  RABINDRASAROVAR NATIONAL LAKE,\nCALCUTTA, WEST...
# 616     2544.0                              SAHEBBANDH AT PURULIA
# 617     2522.0                        SINCHAL LAKE FOR DARJEELING
# 618     2521.0          WATER RESERVIOR AT DELO LAKE,\nDARJELLING
# 619     4725.0                  WATER RESERVIOR ST. HELENS SCHOOL
#
#     Type Water Body      State Name  TemperatureC (Min)  Temperature C (Max)  \
# 0              LAKE  ANDHRA PRADESH                24.0                 27.0
# ...

# %%
# Export to CSV (to use in others scripts)
processed_data_lakes.to_csv("out\processed_data_lakes.csv")

# %%
# Correlation among the data
correlation_lakes = processed_data_lakes.iloc[:,4:].corr()
print(correlation_lakes)
# Out:
#                                    TemperatureC (Min)  Temperature C (Max)  \
# TemperatureC (Min)                           1.000000             0.150358
# Temperature C (Max)                          0.150358             1.000000
# Dissolved Oxygen (mg/L) (Min)               -0.388026            -0.049583
# Dissolved Oxygen (mg/L) (Max)               -0.257293             0.004432
# pH (Min)                                    -0.107983             0.228485
# pH (Max)                                     0.038563             0.241141
# Conductivity (?mhos/cm) (Min)                0.065990            -0.027398
# Conductivity (?mhos/cm) (Max)                0.056684             0.063765
# BOD (mg/L) (Min)                             0.244600             0.040446
# BOD (mg/L) (Max)                             0.198532            -0.171790
# Nitrate N + Nitrite N(mg/L) (Min)            0.032831            -0.033988
# ...

# %%
fig = plt.subplots(figsize=(15,10))  
sns.heatmap(correlation_lakes,annot=True,cmap='coolwarm',linewidths=5,linecolor='black', vmin=0.5,vmax=1,cbar=True)
plt.show()
# The Heat maps doesn't show any strong relationship among anyvariable.

# %%
sns.pairplot(data=processed_data_lakes.iloc[:,4:], corner=True,
x_vars=["TemperatureC (Min)", "Dissolved Oxygen (mg/L) (Min)", "Conductivity (?mhos/cm) (Min)", "BOD (mg/L) (Min)","Nitrate N + Nitrite N(mg/L) (Min)","Total Coliform (MPN/100ml) (Min)"],
y_vars=["TemperatureC (Min)", "Dissolved Oxygen (mg/L) (Min)", "Conductivity (?mhos/cm) (Min)", "BOD (mg/L) (Min)","Nitrate N + Nitrite N(mg/L) (Min)","Total Coliform (MPN/100ml) (Min)"])
# The pairplot for lakes isn't clear about the relationship as the covariance matrix done above

# %%
# Fin outliers 
outlier_ph = detect_outliers(processed_data_lakes,"pH (Min)")
print(outlier_ph)
# Out:
# There are 10 outliers in variable pH (Min) (1.8450184501845017%), and correspond to the indixes: [79, 260, 97, 260, 267, 260, 434, 260, 435, 260]
# None

# %%
outlier_tmin = detect_outliers(processed_data_lakes,"TemperatureC (Min)")
print(outlier_tmin)
# Out:
# There are 34 outliers in variable TemperatureC (Min) (6.273062730627306%), and correspond to the indixes: [79, 70, 72, 116, 118, 119, 371, 396, 417, 428, 605, 606, 610, 614, 617, 618, 619, 80, 70, 72, 116, 118, 119, 371, 396, 417, 428, 605, 606, 610, 614, 617, 618, 619]
# None

# %%
outlier_dissolvedO2 = detect_outliers(processed_data_lakes,"Dissolved Oxygen (mg/L) (Min)")
print(outlier_dissolvedO2)
# Out:
# There are 0 outliers in variable Dissolved Oxygen (mg/L) (Min) (0.0%), and correspond to the indixes: []
# None

# %%
outlier_conducti = detect_outliers(processed_data_lakes,"Conductivity (?mhos/cm) (Min)")
print(outlier_conducti)
# Out:
# There are 21 outliers in variable Conductivity (?mhos/cm) (Min) (3.8745387453874542%), and correspond to the indixes: [2, 8, 10, 12, 78, 97, 101, 102, 322, 327, 413, 452, 478, 490, 538, 556, 559, 562, 563, 569, 575]
# None

# %%
outlier_BOD = detect_outliers(processed_data_lakes,"BOD (mg/L) (Min)")
print(outlier_BOD)
# Out:
# There are 24 outliers in variable BOD (mg/L) (Min) (4.428044280442804%), and correspond to the indixes: [27, 34, 39, 41, 78, 79, 80, 102, 110, 163, 170, 173, 214, 258, 269, 288, 514, 537, 538, 552, 556, 559, 567, 569]
# None

# %%
outlier_Nitra = detect_outliers(processed_data_lakes,"Nitrate N + Nitrite N(mg/L) (Min)")
print(outlier_Nitra)
# Out:
# There are 58 outliers in variable Nitrate N + Nitrite N(mg/L) (Min) (10.70110701107011%), and correspond to the indixes: [352, 356, 430, 447, 458, 459, 460, 462, 463, 465, 466, 467, 474, 475, 478, 480, 483, 485, 488, 490, 491, 494, 497, 505, 508, 509, 510, 511, 512, 514, 515, 517, 521, 526, 530, 531, 534, 538, 546, 550, 551, 552, 554, 556, 557, 559, 561, 562, 563, 564, 566, 568, 570, 573, 577, 578, 579, 582]
# None

# %%
outlier_coliformT = detect_outliers(processed_data_lakes,"Total Coliform (MPN/100ml) (Min)")
print(outlier_coliformT)
# Out:
# There are 117 outliers in variable Total Coliform (MPN/100ml) (Min) (21.58671586715867%), and correspond to the indixes: [78, 113, 156, 157, 158, 159, 161, 162, 163, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 196, 197, 198, 202, 203, 204, 205, 206, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 233, 234, 235, 237, 240, 242, 243, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 259, 260, 265, 268, 269, 273, 274, 279, 281, 282, 283, 284, 285, 286, 287, 288, 290, 291, 293, 294, 299, 300, 301, 309, 312, 315, 316, 317, 319, 320, 602, 613]
# None

# %%
# I get the mean in excel for out file
# Upcoming step in binary class.ipynb
